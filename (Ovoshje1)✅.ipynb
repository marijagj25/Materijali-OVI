# %% [markdown]
# Разгледуваме множество податоци за печурки. Целта е да умееме да ги разликуваме дали некоја печурка се јаде или пак е отровна, имајќи ги предвид физичките својства на печурките, добиени со помош рачно испитување. Податоците со кои располагаме се дадени во табелата подолу.

# %%
import pandas as pd

# %%
df = pd.read_csv('mushrooms.csv')
df
# Out:
#      poisonous cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0            p         x           y         w       t    p               f
# 1            e         x           s         g       f    n               f
# 2            e         x           y         y       t    a               f
# 3            e         b           s         w       t    a               f
# 4            e         b           y         w       t    l               f
# ...        ...       ...         ...       ...     ...  ...             ...
# 8116         e         k           s         n       f    n               a
# 8117         e         x           s         n       f    n               a
# 8118         e         f           s         n       f    n               a
# 8119         p         k           y         n       f    y               f
# 8120         e         x           s         n       f    n               a
#
# ...

# %% [raw]
#  Избројте колку од кафените шумски печурки се отровни.

# %%
data_set = df[
    (df['poisonous'] == 'p') &
    (df['cap-color'] == 'n') &
    (df['habitat'] == 'w')
]['poisonous']

data_set.count()
# Out:
# np.int64(0)

# %% [raw]
# **(6 поени)** Подели го податочното множество на два дела. Поголемиот дел нека е 75% и ќе служи за тренирање, а помалиот дел од 25% ќе служи за проверка на повединието на алгоритмите кои ќе ги имплементираш понатаму.

# %%
from sklearn.model_selection import train_test_split

# %%
df_x = df.iloc[:, 1:]
df_x_encoded = pd.get_dummies(df_x)
df_x
# Out:
#      cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0            x           y         w       t    p               f
# 1            x           s         g       f    n               f
# 2            x           y         y       t    a               f
# 3            b           s         w       t    a               f
# 4            b           y         w       t    l               f
# ...        ...         ...       ...     ...  ...             ...
# 8116         k           s         n       f    n               a
# 8117         x           s         n       f    n               a
# 8118         f           s         n       f    n               a
# 8119         k           y         n       f    y               f
# 8120         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color stalk-shape  ...  \
# 0               c         n          n           e  ...
# 1               w         b          k           t  ...
# ...

# %%
df_y = df['poisonous']
df_y
# Out:
# 0       p
# 1       e
# 2       e
# 3       e
# 4       e
#        ..
# 8116    e
# 8117    e
# 8118    e
# 8119    p
# 8120    e
# Name: poisonous, Length: 8121, dtype: object

# %%
df_train_x, df_test_x, df_train_y, df_test_y = train_test_split(df_x_encoded, df_y, test_size=0.25, random_state=156)
df_test_x
#ja pishuuvame vrednosta na testot vo %
# Out:
#       cap-shape_b  cap-shape_c  cap-shape_f  cap-shape_k  cap-shape_s  \
# 7239        False        False        False         True        False
# 6346        False        False         True        False        False
# 1754        False        False        False        False        False
# 313         False        False        False        False        False
# 6654        False        False        False        False        False
# ...           ...          ...          ...          ...          ...
# 1897        False        False         True        False        False
# 6592        False        False        False        False        False
# 4992        False        False         True        False        False
# 7868         True        False        False        False        False
# 5915        False        False        False        False        False
#
#       cap-shape_x  cap-surface_f  cap-surface_g  cap-surface_s  cap-surface_y  \
# ...

# %% [markdown]
# ### Задача 2.3
# **(6 поени) (код)** Користејќи ја библиотеката `sklearn`,  вчитајте невронска мрежа од типот `Multi-layer Perceptron`, претставено преку класата `MLPClassifier`, а потоа вметнетe ги податоците за тренирање од вториот чекор за да ја истренирате мрежата.
#
# - [Пример за невронски мрежи од sklearn](https://scikit-learn.org/stable/modules/neural_networks_supervised.html#multi-layer-perceptron)
# - [Документација за Multi-layer Perceptron](https://scikit-learn.org/stable/modules/generated/sklearn.neural_network.MLPClassifier.html#sklearn.neural_network.MLPClassifier)

# %%
df_x_encoded
# Out:
#       cap-shape_b  cap-shape_c  cap-shape_f  cap-shape_k  cap-shape_s  \
# 0           False        False        False        False        False
# 1           False        False        False        False        False
# 2           False        False        False        False        False
# 3            True        False        False        False        False
# 4            True        False        False        False        False
# ...           ...          ...          ...          ...          ...
# 8116        False        False        False         True        False
# 8117        False        False        False        False        False
# 8118        False        False         True        False        False
# 8119        False        False        False         True        False
# 8120        False        False        False        False        False
#
#       cap-shape_x  cap-surface_f  cap-surface_g  cap-surface_s  cap-surface_y  \
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

df_x_train_scaled = scaler.fit_transform(df_train_x)
df_x_test_scaled = scaler.transform(df_test_x)

# %%
from sklearn.neural_network import MLPClassifier

# %%
mlp = MLPClassifier(
    hidden_layer_sizes=(50, ),
    activation='relu',
    solver='adam',
    max_iter=1000,
    random_state=84
)

mlp.fit(df_x_train_scaled, df_train_y)
# Out:
# MLPClassifier(hidden_layer_sizes=(50,), max_iter=1000, random_state=84)

# %% [markdown]
# ### Задача 2.4
# **(6 поени)** Пресметај ја прецизноста на алгоритамот за податоците кои тој ги нема видено (на кои нема тренирано). Потоа пресметај ја прецизноста на алгоритамот за податоците кои ги има видено (на кои има тренирано). Споредете ги резултатите. Ви изгледаат ли во ред?

# %%
mlp.fit(df_train_x, df_train_y)
# Out:
# MLPClassifier(hidden_layer_sizes=(50,), max_iter=1000, random_state=84)

# %% [markdown]
# ### Задача 2.5
# **(6 поени) (код)** Што значи тренирање на една невронска мрежа?

# %% [markdown]
# ### Задача 2.6
# **(6 поени) (код)** Кои печурки алгоритамот успева да ги распознава подобро, шумските или ливадските?

# %% [markdown]
# ### Задача 2.7
# **(6 поени)** Дали се отровни печурките од податочното множество од датотеката `mushrooms_test.csv`?

# %%
df_new = pd.read_csv('mushrooms_test.csv')
df_new
# Out:
#   cap-shape cap-surface cap-color bruises odor gill-attachment gill-spacing  \
# 0         x           s         n       t    p               f            c
# 1         x           s         y       t    a               f            c
# 2         b           s         w       t    l               f            c
#
#   gill-size gill-color stalk-shape  ... stalk-surface-below-ring  \
# 0         n          k           e  ...                        s
# 1         b          k           e  ...                        s
# 2         b          n           e  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# 1                      w                      w         p          w
# 2                      w                      w         p          w
#
#   ring-number ring-type spore-print-color population habitat
# ...

# %%
df_new_encoded = pd.get_dummies(df_new)
df_new_encoded
# Out:
#    cap-shape_b  cap-shape_x  cap-surface_s  cap-color_n  cap-color_w  \
# 0        False         True           True         True        False
# 1        False         True           True        False        False
# 2         True        False           True        False         True
#
#    cap-color_y  bruises_t  odor_a  odor_l  odor_p  ...  veil-color_w  \
# 0        False       True   False   False    True  ...          True
# 1         True       True    True   False   False  ...          True
# 2        False       True   False    True   False  ...          True
#
#    ring-number_o  ring-type_p  spore-print-color_k  spore-print-color_n  \
# 0           True         True                 True                False
# 1           True         True                False                 True
# 2           True         True                False                 True
#
#    population_n  population_s  habitat_g  habitat_m  habitat_u
# ...

# %% [markdown]
# ### Задача 2.8
# **(6 поени)** Дали постапуваме правилно ако за нашите податоци имплементираме многу различни алгоритми, на пример над 20, и го избереме најдобриот? Дали сигурно сме го избрале најдобриот или има нешто труло во оваа постапка? Објасни.

# %% [markdown]
# Иако може да изгледа дека со пробување на многу алгоритми сигурно ќе го најдеме најдобриот, тоа не мора да биде точно. Некој модел може да има најдобар резултат само затоа што добро се погодил со тест податоците, а не затоа што навистина е најквалитетен. Поради тоа постои ризик да донесеме погрешен заклучок.

# %% [markdown]
# ### Задача 2.9
# **(6 поени)** Наведи три причини зошто би го избрал овој алгоритам наместо останатите алгоритми (кои ги користевме на часовите).

# %% [markdown]
# 1. Би го избрал овој алгоритам затоа што може да моделира сложени и нелинеарни односи меѓу податоците, што другите поедноставни алгоритми тешко го прават.
#
# 2. MLP често дава подобри резултати (поголема точност) кога има многу карактеристики и доволно податоци за тренирање.
#
# 3. Алгоритмот е флексибилен, бидејќи со менување на бројот на слоеви и неврони може да се прилагоди на различни типови проблеми.

# %% [markdown]
# ### Задача 2.10
# **(6 поени)** Објасни што значи стапка за учење кај ваков тип на алгоритми.

# %% [markdown]
# Стапката за учење (learning rate) покажува колку големи чекори прави алгоритмот при учењето. Таа одредува колку брзо се менуваат тежините во невронската мрежа додека се обидува да ја намали грешката. Ако стапката за учење е преголема, моделот може да „прескокнува“ добро решение и да не научи правилно, а ако е премала, учењето ќе биде многу бавно.
